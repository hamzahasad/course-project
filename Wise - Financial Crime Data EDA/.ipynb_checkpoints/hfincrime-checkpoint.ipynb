# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style("white")

# %%
df_raw = pd.read_csv('homework_dataset.csv')

# %%
df_raw.head().transpose()
# Out:
#                                                                  0  \
# user_id                           77656618388e134648db01eecf7e79ee
# request_id                        2e9f911150e3a79e8d71a35779706e4c
# target_recipient_id               992e0a729d6380d3b50aef5aa7c22572
# date_user_created                                 27/01/2014 15:02
# addr_country_code                                              DEU
# addr_city                                                   Berlin
# recipient_country_code                                          GB
# flag_personal_business                                    Personal
# payment_type                                          Direct Debit
# date_request_submitted                            26/08/2016 07:35
# date_request_received                             01/09/2016 08:31
# date_request_transferred                          01/09/2016 09:28
# date_request_cancelled                                         NaN
# invoice_value                                           155.812339
# invoice_value_cancel                                           NaN
# flag_transferred                                                 1
# payment_status                                         Transferred
# ccy_send                                                       EUR
# ccy_target                                                     GBP
# transfer_to_self                                   Other Recipient
# sending_bank_name                                    Other/unknown
# sending_bank_country                                 Other/unknown
# payment_reference_classification                              gift
# device                                                 Desktop Web
# transfer_sequence                                             55.0
# days_since_previous_req                                        0.0
# first_attempt_date                                27/01/2014 16:01
# first_success_date                                27/01/2014 16:17
#
#                                                                  1  \
# user_id                           a2497e0c763a7e5640fbf05e53fe0466
# request_id                        69cdf2f9ab2f59d10b636dc86bc9d7b7
# target_recipient_id               02878ea857dbc90b2ed89b8f3488d501
# date_user_created                                 12/10/2015 15:35
# addr_country_code                                              CAN
# addr_city                                                  toronto
# recipient_country_code                                          US
# flag_personal_business                                    Personal
# payment_type                                                   NaN
# date_request_submitted                            23/10/2016 22:54
# date_request_received                                          NaN
# date_request_transferred                                       NaN
# date_request_cancelled                            07/11/2016 08:07
# invoice_value                                                  NaN
# invoice_value_cancel                                     59.712044
# flag_transferred                                                 0
# payment_status                                           Cancelled
# ccy_send                                                       CAD
# ccy_target                                                     USD
# transfer_to_self                                   Other Recipient
# sending_bank_name                                    Other/unknown
# sending_bank_country                                 Other/unknown
# payment_reference_classification                           expense
# device                                                     iOS App
# transfer_sequence                                              1.0
# days_since_previous_req                                        NaN
# first_attempt_date                                23/10/2016 22:54
# first_success_date                                27/10/2016 16:45
#
#                                                                  2  \
# user_id                           759735d092819085c125a5cf81faf24b
# request_id                        5d7d30d709268f22f1a73ddbd6601690
# target_recipient_id               927d3808cdc31d61226ae7c80bc8de16
# date_user_created                                 04/10/2016 11:42
# addr_country_code                                              GBR
# addr_city                                                   bolton
# recipient_country_code                                          PT
# flag_personal_business                                    Personal
# payment_type                                         Bank Transfer
# date_request_submitted                            26/10/2016 13:42
# date_request_received                             26/10/2016 14:06
# date_request_transferred                          26/10/2016 14:20
# date_request_cancelled                                         NaN
# invoice_value                                               5000.0
# invoice_value_cancel                                           NaN
# flag_transferred                                                 1
# payment_status                                         Transferred
# ccy_send                                                       GBP
# ccy_target                                                     EUR
# transfer_to_self                  Self-recipient: Exact name match
# sending_bank_name                    NATIONAL WESTMINSTER BANK PLC
# sending_bank_country                                            GB
# payment_reference_classification                             blank
# device                                                 Android App
# transfer_sequence                                             10.0
# days_since_previous_req                                        1.0
# first_attempt_date                                04/10/2016 12:27
# first_success_date                                04/10/2016 16:59
#
#                                                                  3  \
# user_id                           df9627db375322e65f4648ca72f4c630
# request_id                        0df2fc0a4a31595678cd1de3fad57e15
# target_recipient_id               0411b7eb4c220a14876e77da8125f79b
# date_user_created                                 17/10/2014 00:27
# addr_country_code                                              GBR
# addr_city                                                  swindon
# recipient_country_code                                          IN
# flag_personal_business                                    Personal
# payment_type                                                 Cards
# date_request_submitted                            28/01/2015 23:36
# date_request_received                             28/01/2015 23:36
# date_request_transferred                          29/01/2015 07:14
# date_request_cancelled                                         NaN
# invoice_value                                                150.0
# invoice_value_cancel                                           NaN
# flag_transferred                                                 1
# payment_status                                         Transferred
# ccy_send                                                       GBP
# ccy_target                                                     INR
# transfer_to_self                       Self-recipient: Email match
# sending_bank_name                                    Other/unknown
# sending_bank_country                                 Other/unknown
# payment_reference_classification                              loan
# device                                                  Mobile Web
# transfer_sequence                                              9.0
# days_since_previous_req                                        2.0
# first_attempt_date                                19/10/2014 22:00
# first_success_date                                24/11/2014 07:32
#
#                                                                  4
# user_id                           5672b2f16063ed75fbb304fee57c024b
# request_id                        7dcbf32659ae5ef61e10e5174a314d7d
# target_recipient_id               dc248a1266709a71e45c40f33056bbb1
# date_user_created                                 12/08/2015 07:45
# addr_country_code                                              FRA
# addr_city                                                    paris
# recipient_country_code                                          GB
# flag_personal_business                                    Personal
# payment_type                                                 Cards
# date_request_submitted                            18/08/2015 08:55
# date_request_received                             18/08/2015 09:12
# date_request_transferred                          18/08/2015 09:44
# date_request_cancelled                                         NaN
# invoice_value                                           600.130515
# invoice_value_cancel                                           NaN
# flag_transferred                                                 1
# payment_status                                         Transferred
# ccy_send                                                       EUR
# ccy_target                                                     GBP
# transfer_to_self                                   Other Recipient
# sending_bank_name                                LA BANQUE POSTALE
# sending_bank_country                                            FR
# payment_reference_classification                             blank
# device                                                 Desktop Web
# transfer_sequence                                              1.0
# days_since_previous_req                                        NaN
# first_attempt_date                                18/08/2015 08:55
# first_success_date                                18/08/2015 09:44

# %%
df_clean = df_raw['payment_status'] != 'Cancelled'
df_clean = df_raw[['user_id','target_recipient_id', 'date_user_created', 'request_id',
        'recipient_country_code',
       'flag_personal_business', 'payment_type', 'date_request_submitted', 'invoice_value', 
        'payment_status', 
       'transfer_to_self',
       'payment_reference_classification', 'device', 'transfer_sequence',
       'days_since_previous_req', 'first_attempt_date', 'first_success_date']]
df_clean['tenure_acc_created_days'] =  (pd.to_datetime(df_raw['date_request_submitted'].str[0:10], format='%d/%m/%Y', errors='ignore') - pd.to_datetime(df_raw['date_user_created'].str[0:10], format='%d/%m/%Y', errors='ignore')).dt.days
df_clean = df_clean[df_clean['tenure_acc_created_days']>0]
# Out:
# <ipython-input-121-4a3403a17fd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['tenure_acc_created_days'] =  (pd.to_datetime(df_raw['date_request_submitted'].str[0:10], format='%d/%m/%Y', errors='ignore') - pd.to_datetime(df_raw['date_user_created'].str[0:10], format='%d/%m/%Y', errors='ignore')).dt.days

# %%
df_big = df_clean[df_clean['invoice_value'] >= 4965.99]

# %% [markdown]
# ### Grouping user

# %%
df_user = df_clean.groupby(['user_id'], as_index = False).agg({
   'request_id':'nunique',
    'target_recipient_id' :'nunique',
    'date_user_created' :  'min',
#     'addr_country_code':'nunique',
#     'addr_city':'nunique',
    'recipient_country_code' :'nunique',
    'flag_personal_business' : 'nunique',
    'payment_type' : 'nunique',
    'invoice_value' : 'sum',
    'transfer_sequence' : 'max',
    'tenure_acc_created_days' : 'max'
#     'first_attempt_date': 'min',
# 'first_success_date' : 'min' 
})

# %%
df_rec_susp = df_recipient.sort_values(['user_id'], ascending = False).head(15)
df_network = df_clean[df_clean['target_recipient_id'].isin(df_rec_susp['target_recipient_id'])]

# %%
df_network[df_network['target_recipient_id'] == '3b66475e924ac6f5cdb845930d772529'].sort_values()
# Out:
#                     target_recipient_id  request_id  user_id  \
# 22069  3b66475e924ac6f5cdb845930d772529          16        6
# 31732  55602ba1d012407008f2c555b98fa9ef           6        6
# 89265  f144f57b8e574a181463aed16a6092e3           5        5
# 3880   0aa79d6a6ca2c2770ee188d62b162516           4        4
# 48503  828cf566b7a7a6704f3d938c4611e28b           3        3
# 22796  3d3cf197e19aa043632a819c6dc61fea           3        3
# 63567  abb175b16259c2ae14a7931b3eac8179           3        3
# 38976  68ed5258129ad61168862cc9bba5f3cf           2        2
# 33022  59037e0fe3ecc9c7e6115d6ed5c9d42a           2        2
# 80868  db1315683c634ff7ba7797c97c7e6511           2        2
# 67987  b7b73134d7285b00162aa3c566fc5267           2        2
# 54053  919db852fb509d98577755f5241cfac0           2        2
# 43745  75af4925a0789aa731b39c827aabe3fe           3        2
# 52488  8d513ee17ae8f0ef3c1e12ae99a86046           2        2
# 30527  52087100703aa4bb69c68aca235831b3           2        2
#
#       date_user_created  addr_country_code  addr_city  recipient_country_code  \
# 22069  04/07/2013 17:30                  3          6                       1
# 31732  06/05/2016 14:00                  5          6                       1
# 89265  07/02/2016 22:41                  4          5                       1
# 3880   15/06/2016 11:40                  4          4                       1
# 48503  21/07/2016 16:26                  3          3                       1
# 22796  08/11/2015 09:06                  1          3                       1
# 63567  06/03/2016 20:40                  1          3                       1
# 38976  12/01/2016 08:52                  1          1                       1
# 33022  08/08/2016 19:10                  1          2                       1
# 80868  29/07/2016 00:53                  1          2                       1
# 67987  01/07/2016 12:33                  1          2                       1
# 54053  13/04/2016 03:36                  2          2                       1
# 43745  18/10/2014 14:07                  1          1                       1
# 52488  04/10/2016 08:15                  1          2                       1
# 30527  04/12/2013 21:21                  2          2                       1
#
#        flag_personal_business  payment_type  invoice_value  transfer_sequence
# 22069                       2             2    2548.716178             1429.0
# 31732                       1             1     399.174792                1.0
# 89265                       1             2    1648.719326                4.0
# 3880                        1             1      61.611661                1.0
# 48503                       1             1     923.576804               10.0
# 22796                       1             1    7928.714675                2.0
# 63567                       1             1    1423.340000                6.0
# 38976                       1             1      10.000000               52.0
# 33022                       2             2     395.000000                2.0
# 80868                       1             1     967.232000                4.0
# 67987                       1             0       0.000000                3.0
# 54053                       1             1    1391.907500               12.0
# 43745                       1             1    1783.008118               43.0
# 52488                       1             1    1281.690000                1.0
# 30527                       1             2     367.063200               74.0

# %%
x = df_user[(df_user['invoice_value'] >= 2700) & (df_user['tenure_acc_created_days'] <= 10000)]

x.sort_values(['request_id'], ascending = False).head(15)
# Out:
#                                 user_id  request_id  target_recipient_id  \
# 32254  69fd02c4fbd5bfa6533f7a5eac3bd81c          80                   80
# 7859   19466121d8747bd79d1ec4d109b63c52          46                   46
# 53612  b0c7ae2316c7e8214fd659e4bc8a0dea          24                   19
# 71004  e91068fff3d7fa1594dfdf3b4308433a          14                    6
# 18617  3c8ad764022826cb1e0a2c3ee6d85ef4          13                   10
# 70028  e608d060011ee543263f345f9887c6c4          13                   13
# 25743  54391c872fe1c8b4f98095c5d6ec7ec7          12                   11
# 61652  cb57cdb7cc459dc6fbbc33f91485b5e2          12                   12
# 67428  ddb3a4dd1e14f550e64c449bd8b333c3          11                   11
# 63192  d045c59a90d7587d8d671b5f5aec4e7c           9                    9
# 3012   09e77338448191698acbc7799d6b779f           8                    6
# 31144  66438e4d1a3326019fffc7f05428fd9c           8                    7
# 36583  781877bda0783aac5f1cf765c128b437           8                    7
# 36931  79286674060c5b8f6644bfff4ae069a2           8                    6
# 40024  8383c527178a4bf99f08547aac1340e9           7                    6
#
#       date_user_created  recipient_country_code  flag_personal_business  \
# 32254  26/11/2014 11:04                       4                       1
# 7859   21/03/2014 16:11                       4                       2
# 53612  02/09/2012 20:18                       4                       1
# 71004  18/04/2012 08:21                       4                       2
# 18617  27/11/2013 16:57                       4                       1
# 70028  05/01/2015 07:36                       1                       1
# 25743  13/08/2012 13:49                       3                       1
# 61652  19/12/2012 12:19                       5                       1
# 67428  02/03/2015 10:47                       8                       1
# 63192  26/07/2011 13:44                       7                       1
# 3012   05/11/2014 22:54                       2                       2
# 31144  14/04/2014 16:03                       3                       2
# 36583  11/10/2012 13:52                       6                       1
# 36931  29/11/2012 15:53                       4                       1
# 40024  13/04/2014 18:18                       1                       1
#
#        payment_type  invoice_value  transfer_sequence  tenure_acc_created_days
# 32254             1   11291.172933             9239.0                      737
# 7859              1   12403.795251             4733.0                      929
# 53612             1    4649.650000             1952.0                     1521
# 71004             2    2957.989768             1239.0                     1379
# 18617             2   31383.840000              838.0                     1080
# 70028             1    2747.174387             1542.0                      680
# 25743             1   60644.636536             1603.0                     1565
# 61652             1    5345.480000             1180.0                     1413
# 67428             1   13268.660000              957.0                      627
# 63192             1    5335.700000             1325.0                     1847
# 3012              1    3621.730000              354.0                      706
# 31144             1    3322.150000              598.0                      707
# 36583             1    4373.340000              783.0                     1294
# 36931             1   94215.090442              802.0                     1419
# 40024             1    3413.404531              931.0                      939

# %% [markdown]
# ### EDA Categorical

# %%
cat_columns = ['addr_country_code', 'addr_city', 'recipient_country_code',
       'flag_personal_business', 'payment_status', 'payment_type', 'ccy_send', 'ccy_target',
       'transfer_to_self', 'sending_bank_country', 'device']
df_categorical = df_raw[cat_columns]

# %%
for column in df_categorical.columns:
    sns.barplot(x=df_categorical[column].value_counts().index,
                 y=df_categorical[column].value_counts(normalize = True))
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 26481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20096 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31637 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 38754 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 40575 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20816 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23798 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 30476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23627 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 30000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24029 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23822 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 27941 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26481 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20024 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20096 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31637 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38754 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24066 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 40575 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20816 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23798 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30476 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21476 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23627 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21322 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24029 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23822 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 39640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27941 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### EDA Numerical
# - transfer amount
# - transfer amount per user
# - num transfer per user
# - tenure
# - tenure account vs transfer numb & amount
# - tenure vs account destination

# %%
# x = np.log(df_raw['invoice_value'])
x = df_clean[(df_clean['invoice_value']<10000000)]['invoice_value']
sns.boxplot(x)
line1 = plt.axvline(x.quantile(.90), color="y", linestyle="--", label = "percentile_90")
line2 = plt.axvline(x.quantile(.99), color="r", linestyle="--", label = "percentile_99")
first_legend = plt.legend(handles=[line1, line2], loc=1)
print("Mean:", x.mean())
print("Median:", x.median())
print("percentile90:", x.quantile(.9))
print("percentile95:", x.quantile(.95))
print("percentile99:", x.quantile(.99))
print("Std Dev:", x.std())
plt.show()
# Out:
# Mean: 1404.9672245707766
# Median: 429.2915
# percentile90: 2698.2418400000006
# percentile95: 5000.0
# percentile99: 15824.458799999959
# Std Dev: 6399.450089121376
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = df_clean[(df_clean['invoice_value']<=15824.46)]['invoice_value']
sns.boxplot(x)
line1 = plt.axvline(2700, color="y", linestyle="--", label = "invoice 2700")
first_legend = plt.legend(handles=[line1], loc=1)
print("Mean:", x.mean())
print("Median:", x.median())
print("percentile90:", x.quantile(.9))
print("percentile95:", x.quantile(.95))
print("percentile99:", x.quantile(.99))
print("Std Dev:", x.std())
plt.show()
# Out:
# Mean: 1040.6226120929741
# Median: 421.772
# percentile90: 2494.6036249999997
# percentile95: 4112.10471225
# percentile99: 10000.0
# Std Dev: 1779.031508969256
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = df_user['transfer_sequence']
sns.boxplot(x)
line1 = plt.axvline(x.median(), color="y", linestyle="--", label = "Median")
first_legend = plt.legend(handles=[line1], loc=1)
print("Mean:", x.mean())
print("Median:", x.median())
print("percentile90:", x.quantile(.9))
print("percentile95:", x.quantile(.95))
print("percentile99:", x.quantile(.99))
print("Std Dev:", x.std())
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Mean: 15.447062112148489
# Median: 7.0
# percentile90: 33.0
# percentile95: 50.0
# percentile99: 115.0
# Std Dev: 104.48709934402694

# %%
x = df_clean['tenure_acc_created_days']
sns.boxplot(x)
line1 = plt.axvline(x.median(), color="y", linestyle="--", label = "Median")
first_legend = plt.legend(handles=[line1], loc=1)
print("Mean:", x.mean())
print("Median:", x.median())
print("percentile25:", x.quantile(.25))
print("percentile95:", x.quantile(.95))
print("percentile99:", x.quantile(.99))
print("Std Dev:", x.std())
plt.show()
# Out:
# Mean: 274.5939357434283
# Median: 202.0
# percentile25: 68.0
# percentile95: 783.0
# percentile99: 1088.0
# Std Dev: 258.2819513145703
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = df_clean[df_clean['days_since_previous_req']<100]['days_since_previous_req']
sns.distplot(x)
line1 = plt.axvline(x.median(), color="y", linestyle="--", label = "Median")
first_legend = plt.legend(handles=[line1], loc=1)
print("Mean:", x.mean())
print("Median:", x.median())
print("percentile25:", x.quantile(.25))
print("percentile95:", x.quantile(.95))
print("percentile99:", x.quantile(.99))
print("Std Dev:", x.std())
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Mean: 16.82531040947086
# Median: 9.0
# percentile25: 1.0
# percentile95: 62.0
# percentile99: 90.0
# Std Dev: 20.443315579333767

# %% [markdown]
# ### EDA 2 columns

# %%
df_2col = df_clean[['transfer_sequence', 'invoice_value', 'user_id','target_recipient_id', 'tenure_acc_created_days', 'days_since_previous_req']]
df_2col['suspect_transfer'] = np.where((df_clean['transfer_sequence'] <=7)&(df_clean['invoice_value'] >2700), 'risky', 'normal')
df_2col['suspect_tenure'] = np.where((df_clean['tenure_acc_created_days'] <=14)&(df_clean['invoice_value'] >2700), 'risky', 'normal')
df_2col['suspect_prev_req'] = np.where((df_clean['days_since_previous_req'] <=1)&(df_clean['invoice_value'] >2700), 'risky', 'normal')
# Out:
# <ipython-input-134-729ee7c0fb5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2col['suspect_transfer'] = np.where((df_clean['transfer_sequence'] <=7)&(df_clean['invoice_value'] >2700), 'risky', 'normal')
# <ipython-input-134-729ee7c0fb5b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2col['suspect_tenure'] = np.where((df_clean['tenure_acc_created_days'] <=14)&(df_clean['invoice_value'] >2700), 'risky', 'normal')
# <ipython-input-134-729ee7c0fb5b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2col['suspect_prev_req'] = np.where((df_clean['days_since_previous_req'] <=1)&(df_clean['invoice_value'] >2700), 'risky', 'normal')

# %%
#invoice value vs tranfer sequence
sns.relplot(x="invoice_value", y="transfer_sequence", hue = 'suspect_transfer', data=df_2col[(df_2col['transfer_sequence'] <1000)&(df_2col['invoice_value'] <15824.46)])
line1 = plt.axvline(2700, color="r", linestyle="--", label = "invoice percentile 90")
line2 = plt.axhline(7, color="r", linestyle="--", label = "transfer median")
first_legend = plt.legend(handles=[line1, line2], loc=1)
plt.show()

# %%
#invoice value vs tranfer sequence
sns.relplot(x="invoice_value", y="tenure_acc_created_days", hue = 'suspect_tenure', data=df_2col[(df_2col['transfer_sequence'] <1000)&(df_2col['invoice_value'] <15824.46)])
line1 = plt.axvline(2700, color="r", linestyle="--", label = "invoice percentile 90")
line2 = plt.axhline(14, color="r", linestyle="--", label = "tenure 14")
first_legend = plt.legend(handles=[line1, line2], loc=1)
plt.show()

# %%
sns.set(rc={'figure.figsize':(8,12)})

sns.boxplot(x="invoice_value",
                y= 'payment_reference_classification',
                data=df_clean[(df_clean['invoice_value'] <15284)])
line1 = plt.axvline(2700, color="r", linestyle="--", label = "invoice percentile 90")
first_legend = plt.legend(handles=[line1], loc=1)

# %%
sns.boxplot(x="invoice_value",
                y = 'payment_type',
                data=df_clean[(df_clean['transfer_sequence'] <1000)&(df_clean['invoice_value'] <5000)])
# Out:
# <AxesSubplot:xlabel='invoice_value', ylabel='payment_type'>

# %%
sns.boxplot(x="invoice_value",
                y = 'flag_personal_business',
                data=df_clean[(df_clean['transfer_sequence'] <1000)&(df_clean['invoice_value'] <5000)])
# Out:
# <AxesSubplot:xlabel='invoice_value', ylabel='flag_personal_business'>

# %%
sns.boxplot(y="invoice_value",
                x = 'recipient_country_code',
                data=df_clean[(df_clean['transfer_sequence'] <1000)&(df_clean['invoice_value'] <5000)])
# Out:
# <AxesSubplot:xlabel='recipient_country_code', ylabel='invoice_value'>

# %%
sns.boxplot(y="invoice_value",
                x = 'transfer_to_self',
                data=df_clean[(df_clean['transfer_sequence'] <1000)&(df_clean['invoice_value'] <5000)])
# Out:
# <AxesSubplot:xlabel='transfer_to_self', ylabel='invoice_value'>

# %% [markdown]
# ### Network

# %%
from pyvis.network import Network

got_net = Network(height='750px', width='100%', font_color='grey', notebook=True)

# set the physics layout of the network
got_data = df_clean

sources = got_data['Source']
targets = got_data['Target']
# weights = got_data['Weight']

edge_data = zip(sources, targets) #, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
#     w = e[2]

    got_net.add_node(src, src, title=src)
    got_net.add_node(dst, dst, title=dst)
    got_net.add_edge(src, dst)

neighbor_map = got_net.get_adj_list()

# add neighbor data to node hover data
for node in got_net.nodes:
    node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
    node['value'] = len(neighbor_map[node['id']])

got_net.show('gameofthrones.html')
